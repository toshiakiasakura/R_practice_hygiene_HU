# %%
# version check
print(R.version.string)
# Out:
# [1] "R version 4.1.2 (2021-11-01)"

# %% [markdown]
# ### Install

# %%
# Install part.
install.packages("openxlsx", repos='http://cran.us.r-project.org')
# multiple install 
install.packages(c("dplyr","readr"))
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %% [markdown]
# ### Load packages

# %%
# single library import.
library("surveillance")

# multiple library imports. 
Packages <- c("openxlsx", "dplyr", "readr", "ggplot2")
lapply(Packages, library, character.only = TRUE)
# Out:
# Loading required package: sp
#
# Loading required package: xtable
#
# This is surveillance 1.20.0. For overview type ‘help(surveillance)’.
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [[1]]
#  [1] "openxlsx"     "surveillance" "xtable"       "sp"           "stats"
#  [6] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [11] "base"
#
# [[2]]
#  [1] "dplyr"        "openxlsx"     "surveillance" "xtable"       "sp"
#  [6] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [11] "methods"      "base"
#
# [[3]]
#  [1] "readr"        "dplyr"        "openxlsx"     "surveillance" "xtable"
#  [6] "sp"           "stats"        "graphics"     "grDevices"    "utils"
# [11] "datasets"     "methods"      "base"
#
# [[4]]
# ...
